# %%
using Winston

# %% [markdown]
# # Example 1

# %%
 x = collect(range(0, 3pi, 100))
 c = cos.(x)
 s = sin.(x)

 p = FramedPlot(
         title="title!",
         xlabel="\\Sigma x^2_i",
         ylabel="\\Theta_i")

 add(p, FillBetween(x, c, x, s))
 add(p, Curve(x, c, color="red"))
 add(p, Curve(x, s, color="blue"))
# Out:
# FramedPlot(...)

# %%
x
# Out:
# 100-element Vector{Float64}:
#  0.0
#  0.09519977738150888
#  0.19039955476301776
#  0.28559933214452665
#  0.3807991095260355
#  0.47599888690754444
#  0.5711986642890533
#  0.6663984416705622
#  0.761598219052071
#  0.8567979964335799
#  0.9519977738150889
#  1.0471975511965976
#  1.1423973285781066
#  ⋮
#  8.377580409572781
#  8.47278018695429
#  8.5679799643358
#  8.663179741717308
#  8.758379519098817
#  8.853579296480326
#  8.948779073861836
#  9.043978851243343
#  9.139178628624853
#  9.234378406006362
#  9.32957818338787
#  9.42477796076938

# %% [markdown]
# # Example 2

# %%
x = collect(range(pi, 3pi, 60))
c = cos.(x)
s = sin.(x)

p = FramedPlot(aspect_ratio=1)
setattr(p.frame1, draw_grid=true, tickdir=1)

setattr(p.x1, label="bottom", subticks=1)
setattr(p.y1, label="left", draw_spine=false)
setattr(p.x2, label="top", range=(10,1000), log=true)

setattr(p.y2, label="right", draw_ticks=false,
     ticklabels=["-1", "-1/2", "0", "1/2", "1"])

add(p, Curve(x, c, kind="dash"))
add(p, Curve(x, s))
# Out:
# FramedPlot(...)
